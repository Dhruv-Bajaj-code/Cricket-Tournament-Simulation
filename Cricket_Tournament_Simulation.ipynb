# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruv-Bajaj-code/Cricket-Tournament-Simulation/blob/main/Cricket_Tournament_Simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

# %%
class matchh:
  win = int(-1)
  def __init__(self,team1,team2):
      coinToss = math.floor((random.random()))
      print("===========================  "+"team"+str(team1) + " WON THE TOSS "+ "==================================" if coinToss==0 else "===========================  "+"team"+str(team2) + " WON THE TOSS "+ "==================================")
      scoreTeam1=int(0)
      wicketteam1 = 10
      scoreTeam2=int(0)
      wicketteam2 = 10
      c = math.floor(random.random())
      if coinToss==0:
        if(math.floor((random.random()))==0):
          print("\n"+"team" + str(team1) + " chose bating")
          for i in range(0,10):
            a = int(0)
            print("over - " + str(i+1))
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam1 = scoreTeam1 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam1 = wicketteam1 - 1

                print("O ",end="")
                if wicketteam1==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break

          print("team"+str(team2) + "  turns to bat")
          for i in range(0,10):
            a = int(0)
            print("over - " + str(i+1))
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam2 = scoreTeam2 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam2 = wicketteam2 - 1

                print("O ",end="")
                if wicketteam2==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break
        else:
          print("\n"+"team"+str(team1) + " chose to ball")
          for i in range(0,10):
            a = int(0)
            print("over - " + i+1)
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam2 = scoreTeam2 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam2 = wicketteam2 - 1

                print("O ",end="")
                if wicketteam2==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break

          print("team"+str(team2) + "  turns to bat")
          for i in range(0,10):
            a = int(0)
            print("over - " + i+1)
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam1 = scoreTeam1 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam1 = wicketteam1 - 1

                print("O ",end="")
                if wicketteam1==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break
      else:
        if(math.floor((random.random()))==0):
          print("\n"+"team"+str(team2) + " chose bating")
          for i in range(0,10):
            a = int(0)
            print("over - " + str(i+1))
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam2 = scoreTeam2 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam2 = wicketteam2 - 1

                print("O ",end="")
                if wicketteam2==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break

          print("team"+str(team2) + "  turns to bat")
          for i in range(0,10):
            a = int(0)
            print("over - " + i+1)
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam1 = scoreTeam1 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam1 = wicketteam1 - 1

                print("O ",end="")
                if wicketteam1==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break
        else:
          print("\n"+"team"+str(team2) + " chose to ball")
          for i in range(0,10):
            a = int(0)
            print("over - " + str(i+1))
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam1 = scoreTeam1 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam1 = wicketteam1 - 1

                print("O ",end="")
                if wicketteam1==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break

          print("team"+str(team1) + "  turns to bat")
          for i in range(0,10):
            a = int(0)
            print("over - " + i+1)
            for j in range(0,6):
              s = math.floor((random.random())*7)
              if s+1==1 or s+1==2 or s+1==3 or s+1==4 or s+1==6:
                scoreTeam2 = scoreTeam2 + s+1
                print(str(s) + " ",end="")
              elif s+1==5:
                wicketteam2 = wicketteam2 - 1

                print("O ",end="")
                if wicketteam2==0:
                  a = 1
                  break

              elif s+1==7:
                print("W ",end="")
            print("\n")
            if a==1:
              break
      self.win =  team1 if scoreTeam1>scoreTeam2 else team2

# %%
class Players:
  def __init__(self,type,hit,bol):
    self.hit = hit
    self.bol = bol









class tornament:
  Wins=[]
  teamNames=[]
  noOfM = int()
  TeamsLeft = []

  def noOfMatches(self,a):
    noOfM = 0
    while a!=1:
      if a%2==0:
        noOfM = noOfM + a/2
        a = a/2
      else:
        noOfM = noOfM + (a-1)/2
        a = (a-1)/2 + 1
    return noOfM

  def LeaderBoardUpdate(self,team1,team2,winner):
    self.Wins.append([team1,team2,winner])




  def Play(self):
    while len(self.TeamsLeft)!=1:
      i = int(0)
      while(True):
        if i==len(self.TeamsLeft)-1 or i==len(self.TeamsLeft):
          break
        else:
          m1 = matchh(i,i+1)
          a = m1.win
          self.LeaderBoardUpdate(self.TeamsLeft[i],self.TeamsLeft[i+1],self.TeamsLeft[a])
          print(self.TeamsLeft[i] + " VS " + self.TeamsLeft[i+1] + " ===> " + self.TeamsLeft[a] + "WON!")
          self.TeamsLeft.pop(i+1 if a==i else i )
          i = i + 1
      print("----------------------------------------------------------------------------------------------------------------------------------------")



  def __init__(self,noOfTeam,teamNames):
    self.noOfTeam = noOfTeam
    self.noOfM = self.noOfMatches(noOfTeam)
    self.Wins = []
    self.temsNames = teamNames
    self.TeamsLeft = teamNames

if __name__=="__main__":
  t1 = tornament(3,["t1","t2","t3","t4"])


  t1.Play()
# Out:
# ===========================  team0 WON THE TOSS ==================================
#
# team0 chose bating
# over - 1
# 0 5 0 1 O O
#
# over - 2
# 3 5 W W 1 0
#
# over - 3
# 2 W O 5 0 0
#
# over - 4
# 3 1 0 1 1 W
#
# over - 5
# 0 0 W W 1 0
#
# over - 6
# W O 3 3 O 1
#
# over - 7
# 1 2 3 3 2 1
#
# over - 8
# 2 W O W O 5
#
# over - 9
# W 2 3 2 O W
#
# over - 10
# 0 W 1 3 O 0
#
# team1  turns to bat
# over - 1
# O 1 W 1 0 O
#
# over - 2
# 3 3 1 1 2 0
#
# over - 3
# 2 5 5 3 W 5
#
# over - 4
# O 2 3 W O W
#
# over - 5
# W 1 5 0 2 O
#
# over - 6
# 2 O W W 0 3
#
# over - 7
# 0 0 5 5 1 O
#
# over - 8
# W 5 3 1 W 3
#
# over - 9
# O 2 1 2 W 2
#
# over - 10
# 5 3 W W 2 W
#
# t1 VS t2 ===> t2WON!
# ===========================  team1 WON THE TOSS ==================================
#
# team1 chose bating
# over - 1
# W W 5 1 W W
#
# over - 2
# 5 0 0 O 3 3
#
# over - 3
# O 5 0 1 3 5
#
# over - 4
# 5 1 W 2 W 5
#
# over - 5
# 0 W 1 0 5 2
#
# over - 6
# 5 2 1 O O O
#
# over - 7
# O O 2 W W 0
#
# ...
